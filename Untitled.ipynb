# %% [markdown]
# # US accidents

# %% [markdown]
# ## import file and read file

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('archive.zip')

# %% [markdown]
# ## data preperation and cleaning

# %% [markdown]
# ### 1. see number of null values
# ### 2. remove data if necessary
# ### 3. hereafter working with updated dataset

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df=missing_value_df[missing_value_df != 0].sort_values('percent_missing', inplace=False)

# %%
missing_value_df[missing_value_df != 0].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### wont be studing about columns with more than 25% data missing

# %% [raw]
# df = df.drop(columns=['End_Lat','End_Lng','Wind_Chill(F)','Precipitation(in)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %% [markdown]
# ## data visualization

# %% [markdown]
# ## questions
#
# 1. which countries have most accidents
# 2. what is sevierity of most accidents
# 3. plot accidents on map os us
# 4. relation between distance and sevirety more distance should be more sevire
# 5. more accdents in cold or warm relation betweem temperature and accidents happening
# 5. winf chill most of data misssing so we'll skip
# 6. date time month year day of week ke saath relation
# 7. if notice something weird check source for relaibilty

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
countries = df.Country.unique()
len(countries)
# Out:
# 1

# %%
print(countries)
# Out:
# ['US']

# %%
cites_accidents=df.City.value_counts()
cites_accidents[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
cites_accidents[:20].plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
'Williamsburg' in df['City']
# Out:
# False

# %%
sns.histplot(cites_accidents,log_scale = True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
only_single_accident = cites_accidents[cites_accidents==1]

# %%
len(only_single_accident)/len(cities)
# Out:
# 0.07478616857957453

# %%
print(df['Start_Time'])
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
print(df['Start_Time'].dtype)
# Out:
# object

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 05:46:00')

# %%
df['Time'] = df['Start_Time'].dt.time
print(df['Time'])
# Out:
# 0          05:46:00
# 1          06:07:59
# 2          06:49:27
# 3          07:23:34
# 4          07:39:07
#              ...
# 7728389    18:03:25
# 7728390    19:11:30
# 7728391    19:00:21
# 7728392    19:00:21
# 7728393    18:52:06
# Name: Time, Length: 7728394, dtype: object

# %%
df['Hour'] = df['Start_Time'].dt.hour

hour_counts = df['Hour'].value_counts().sort_index()

hour_counts.plot(kind='bar')

plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')
plt.title('Frequency of Events by Hour of the Day')
plt.show()

# %%
df['Year'] = df['Start_Time'].dt.year

Year_counts = df['Year'].value_counts().sort_index()

# %%
year=df.Year.unique()
print(year)
# Out:
# [2016. 2017. 2022. 2021. 2020. 2019. 2018.   nan 2023.]

# %% [markdown]
# # Conclusions
